# %%
#!/usr/bin/python
# -*- coding:utf-8 -*-
import os
import sys
import json
import argparse
import pandas as pd
import statistics
sys.path.append(os.getcwd())
import ray

from base import TaskScanner, run_pyrosetta
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2024 [Rosetta PyRosetta4.conda.ubuntu.cxx11thread.serialization.Ubuntu.python39.Release 2024.42+release.3366cf78a3df04339d1982e94531b77b098ddb99 2024-10-11T08:24:04] retrieved from: http://www.pyrosetta.org

# %% [markdown]
# #### PDB Path

# %%
import pandas as pd

# %%
# pdb_filespath = "/home/lily/SBDD/PocketXMol/results/TNFa/batch6/"
# filenames = os.listdir(pdb_filespath)
# subset = [f for f in filenames if f.endswith("_complex.pdb")][:100]


df = pd.read_csv("/home/lily/SBDD/PocketXMol/TSLP/analysis/TSLP_batch1_step1_filter_5816.csv")
df = df[['merge_key']]
df.columns =['pdb_ids']
pdb_filespath = "/home/lily/SBDD/PocketXMol/TSLP/results"
pdb_path_lst = [str(os.path.join(pdb_filespath,x)) for x in df.pdb_ids.tolist()]
pdb_path_lst[0]
# Out:
# '/home/lily/SBDD/PocketXMol/TSLP/results/ACYKEDVYGPDGSCG_align_pep0_fixed_pxm_20260204_191019_6_complex.pdb'

# %%
df = pd.read_csv("/home/lily/SBDD/PocketXMol/TSLP/analysis/TSLP_batch1_step1_filter_5816.csv")

# %%
df.loc[0,'merge_key']
# Out:
# 'ACYKEDVYGPDGSCG_align_pep0_fixed_pxm_20260204_191019_6_complex.pdb'

# %%
# with open("test_rosetta_path.txt", "w") as f:
#     for item in subset:
#         f.write(str(pdb_filespath+item) + "#AB#C" "\n")

with open("TSLP_batch1_rosetta_5816.txt", "w") as f:
    for item in pdb_path_lst:
        f.write(str(item) + "#A#B" "\n")

# %%
chunks = np.array_split(df.peptide_sequence.tolist(), 8)
chunks = [list(c) for c in chunks] 

for chunk in chunks:
    print(len(chunk))
# Out:
# 727
# 727
# 727
# 727
# 727
# 726
# 726
# 726

# %%
# with open("../run_tslp_batch1_p0.sh", "w") as f:
#     for seq in chunks[0]:
#         example_cmd = f"CUDA_VISIBLE_DEVICES=0 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
#         f.write(str(example_cmd) + "\n")

# with open("../run_tslp_batch1_p1.sh", "w") as f:
#     for seq in chunks[1]:
#         example_cmd = f"CUDA_VISIBLE_DEVICES=0 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
#         f.write(str(example_cmd) + "\n")

# %%
with open("../run_tslp_batch1_p2.sh", "w") as f:
    for seq in chunks[2]:
        example_cmd = f"CUDA_VISIBLE_DEVICES=1 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
        f.write(str(example_cmd) + "\n")

with open("../run_tslp_batch1_p3.sh", "w") as f:
    for seq in chunks[3]:
        example_cmd = f"CUDA_VISIBLE_DEVICES=1 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
        f.write(str(example_cmd) + "\n")

# %%
with open("../run_tslp_batch1_p4.sh", "w") as f:
    for seq in chunks[4]:
        example_cmd = f"CUDA_VISIBLE_DEVICES=2 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
        f.write(str(example_cmd) + "\n")

with open("../run_tslp_batch1_p5.sh", "w") as f:
    for seq in chunks[5]:
        example_cmd = f"CUDA_VISIBLE_DEVICES=2 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
        f.write(str(example_cmd) + "\n")

# %%
with open("../run_tslp_batch1_p6.sh", "w") as f:
    for seq in chunks[6]:
        example_cmd = f"CUDA_VISIBLE_DEVICES=3 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
        f.write(str(example_cmd) + "\n")

with open("../run_tslp_batch1_p7.sh", "w") as f:
    for seq in chunks[7]:
        example_cmd = f"CUDA_VISIBLE_DEVICES=3 boltz predict /home/lily/SBDD/Boltz2/boltz/2026/TSLP_batch1/configs/pep_{seq}.yaml --out_dir ./2026/TSLP_batch1/prediction_results/"
        f.write(str(example_cmd) + "\n")

# %%
pred_cif.replace(".cif","main_chain_complex.pdb")
# Out:
# '/home/lily/SBDD/Boltz2/boltz/result_IL17A_desing_HAP/boltz_results_pep_IHESIDADVWDWSG/predictions/pep_IHESIDADVWDWSG/pep_IHESIDADVWDWSG_model_0main_chain_complex.pdb'

# %% [markdown]
# ### ziqing

# %%
import os
import pandas as pd

# %%
pxm_path = "/home/yangziqing/PocketXMol/"

path_dict = {
    'pepbdb': 'outputs_test/pepdesign_pepbdb/base_pxm_20260325_130506',
    'bpep': 'outputs_test/pepdesign_bpep/base_pxm_20260325_130808',
    'cpep': 'outputs_test/pepdesign_cpep/base_pxm_20260328_141105',
    'pepmerge': 'outputs_test/pepdesign_pepmerge/base_pxm_20260407_132739'
}

# %%
db_list = ['pepbdb', 'bpep', 'cpep', 'pepmerge']
src_list = ['gt', 'gen']
for db in db_list:
    for src in src_list:
        src_path = path_dict[db]
        src_path = os.path.join(pxm_path,src_path)
        pdb_path_list = os.path.join(src_path,f"{db}_rosetta_{src}.txt")
        pdb_path = os.path.join(src_path,f"{src}_combined_rosetta")
        with open(pdb_path_list, "w") as f:
            for item in os.listdir(pdb_path):
                if item.endswith(".pdb") and "_rosetta" not in item: # exclude _rosetta.pdb
                    f.write(str(os.path.join(pdb_path,item)) + "#R#L" "\n")
